# %% [markdown]
# Install TEEHR

# %% [markdown]
# `pip install --user 'teehr @ git+https://github.com/RTIInternational/teehr@main'`

# %% [markdown]
# `pip install --user 'teehr @ git+https://github.com/RTIInternational/teehr@main'`

# %%
pip install --user 'teehr @ git+https://github.com/RTIInternational/teehr@main'
